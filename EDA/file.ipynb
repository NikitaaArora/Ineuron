# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
#import matplotlin_inline as mi

# %%
# %matplotlib inline

# %%
Tel_data= pd.read_csv('Telecom_Churn.csv')
Tel_data
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
Tel_data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  ...  Total night calls  \
# 0             31.37              351.6  ...                 90
# ...

# %%
Tel_data.tail()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 662                     26              137.1               88
# 663                     29               83.6              131
# 664                      0              193.9              118
# 665                      0              169.8              114
# 666                      0              213.8              105
#
#      Total day charge  Total eve minutes  ...  Total night calls  \
# 662             23.31              155.7  ...                 94
# ...

# %%
print("The number of rows are {}".format(Tel_data.shape[0])) #dimensions of data
print("The number of columns are {}".format(Tel_data.shape[1]))
# Out:
# The number of rows are 667
# The number of columns are 23

# %%
Tel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
Tel_data.drop(columns=['Unnamed: 20','Unnamed: 21','Unnamed: 22'],
              axis=1,inplace=True)

# %%
Tel_data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
#Tel_data.describe() #for numerical columns
round(Tel_data.describe().T,2) #transpose: rows become columns and columns become rows
#round to 2 decimal places.
# Out:
#                         count    mean    std     min     25%     50%     75%  \
# Account length          667.0  102.84  40.82    1.00   76.00  102.00  128.00
# Area code               667.0  436.16  41.78  408.00  408.00  415.00  415.00
# Number vmail messages   667.0    8.41  13.99    0.00    0.00    0.00   20.00
# Total day minutes       667.0  180.95  55.51   25.90  146.25  178.30  220.70
# Total day calls         667.0  100.94  20.40   30.00   87.50  101.00  115.00
# Total day charge        667.0   30.76   9.44    4.40   24.86   30.31   37.52
# Total eve minutes       667.0  203.36  49.72   48.10  171.05  203.70  236.45
# Total eve calls         667.0  100.48  18.95   37.00   88.00  101.00  113.00
# Total eve charge        667.0   17.29   4.23    4.09   14.54   17.31   20.10
# Total night minutes     667.0  199.69  49.76   23.20  167.95  201.60  231.50
# Total night calls       667.0  100.11  20.17   42.00   86.00  100.00  113.50
# ...

# %%
#data description

Tel_data_summary = round(Tel_data.describe(include= 'all').T,2)
Tel_data_summary
# round upto 2 decimal places
#includes categorical and numerical columns both.
# mean doesnt come in categorical
# top is mode
# freq: how many times its coming #for categorical columns.
# Out:
#                         count unique    top freq        mean        std  \
# State                     667     51     AZ   19         NaN        NaN
# Account length          667.0    NaN    NaN  NaN  102.841079   40.81948
# Area code               667.0    NaN    NaN  NaN  436.157421  41.783305
# International plan        667      2     No  614         NaN        NaN
# Voice mail plan           667      2     No  478         NaN        NaN
# Number vmail messages   667.0    NaN    NaN  NaN    8.407796   13.99448
# Total day minutes       667.0    NaN    NaN  NaN  180.948126  55.508628
# Total day calls         667.0    NaN    NaN  NaN  100.937031   20.39679
# Total day charge        667.0    NaN    NaN  NaN   30.761769   9.436463
# Total eve minutes       667.0    NaN    NaN  NaN  203.355322  49.719268
# Total eve calls         667.0    NaN    NaN  NaN  100.476762  18.948262
# Total eve charge        667.0    NaN    NaN  NaN   17.285262    4.22616
# ...

# %%
Tel_data.describe(include = 'object').T
# Out:
#                    count unique top freq
# State                667     51  AZ   19
# International plan   667      2  No  614
# Voice mail plan      667      2  No  478

# %%
# This Data Description gives the spread of the data.

Tel_data_summary = round(Tel_data.describe(percentiles=[0.1,0.25,0.5,0.75,0.9]).T,2)
Tel_data_summary

#if mean= median then data is symmetrical follows normal distribution

# 1. In account_length mean is close to 50%(ie. median) ie. data is not very skewed.
# 2. Area code is also a categorical variable. 
# 3. Number vmail messages has median as 0 and mean as 8.41 ie. hardly we have given any voicemail msgs to the customers
# Out:
#                         count    mean    std     min     10%     25%     50%  \
# Account length          667.0  102.84  40.82    1.00   52.60   76.00  102.00
# Area code               667.0  436.16  41.78  408.00  408.00  408.00  415.00
# Number vmail messages   667.0    8.41  13.99    0.00    0.00    0.00    0.00
# Total day minutes       667.0  180.95  55.51   25.90  110.20  146.25  178.30
# Total day calls         667.0  100.94  20.40   30.00   74.60   87.50  101.00
# Total day charge        667.0   30.76   9.44    4.40   18.73   24.86   30.31
# Total eve minutes       667.0  203.36  49.72   48.10  142.06  171.05  203.70
# Total eve calls         667.0  100.48  18.95   37.00   77.00   88.00  101.00
# Total eve charge        667.0   17.29   4.23    4.09   12.08   14.54   17.31
# Total night minutes     667.0  199.69  49.76   23.20  136.16  167.95  201.60
# Total night calls       667.0  100.11  20.17   42.00   75.00   86.00  100.00
# ...

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
Tel_data['State'].unique()
# Out:
# array(['LA', 'IN', 'NY', 'SC', 'HI', 'AK', 'MI', 'ID', 'VA', 'WI', 'MN',
#        'VT', 'MT', 'MA', 'KY', 'CO', 'AZ', 'CA', 'WA', 'NE', 'OH', 'MO',
#        'AL', 'NH', 'NM', 'OR', 'TX', 'MS', 'WY', 'FL', 'KS', 'NC', 'SD',
#        'OK', 'CT', 'RI', 'DE', 'UT', 'NV', 'DC', 'ME', 'IL', 'NJ', 'MD',
#        'WV', 'PA', 'ND', 'AR', 'TN', 'IA', 'GA'], dtype=object)

# %%
for i in Tel_data.columns:
    print(i)
    print(Tel_data[i].unique())
# Out:
# State
# ['LA' 'IN' 'NY' 'SC' 'HI' 'AK' 'MI' 'ID' 'VA' 'WI' 'MN' 'VT' 'MT' 'MA'
#  'KY' 'CO' 'AZ' 'CA' 'WA' 'NE' 'OH' 'MO' 'AL' 'NH' 'NM' 'OR' 'TX' 'MS'
#  'WY' 'FL' 'KS' 'NC' 'SD' 'OK' 'CT' 'RI' 'DE' 'UT' 'NV' 'DC' 'ME' 'IL'
#  'NJ' 'MD' 'WV' 'PA' 'ND' 'AR' 'TN' 'IA' 'GA']
# Account length
# [117  65 161 111  49  36 119  10  68  74  85  46 128 155  73  77 108  95
#  141  63  97  75 127 121   6  32  64  25  93 208 122  99  45 139 215  94
#   86 106  92  78  83 144 143  81 145  89 199  96 124 148 135  87  54  35
#   84 112 129 140  70  79  91 149  60 115 102  55 126  52  67 165 150  26
#   69 157  80  44 101  82  39  30 105 166 172  88 153 109  27   3  43 116
#  107 123 110 176  13 156 158 103 151  90  33 167  38 100 136 120 104   1
#   76 132 114  48  59  50  12 131 217 134  53  72  98 118 130 159  37  29
#  113 163  56  51  66 193   7  71  31 190 170 125 232 182 197  57 137  21
#  191  16  34 146 138  62 201 133 162 195 177  41  61 152 175 160  19 142
# ...

# %%
cat = []
num=[]

# %%
for i in Tel_data.columns:
    if Tel_data[i].dtype == 'object':
        cat.append(i)
    else:
        num.append(i)

# %%
cat
# Out:
# ['State', 'International plan', 'Voice mail plan']

# %%
num
# Out:
# ['Account length',
#  'Area code',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
#doesnt make sense to unique for numerical cols
for i in cat:
    print(i)
    print(Tel_data[i].unique())
# Out:
# State
# ['LA' 'IN' 'NY' 'SC' 'HI' 'AK' 'MI' 'ID' 'VA' 'WI' 'MN' 'VT' 'MT' 'MA'
#  'KY' 'CO' 'AZ' 'CA' 'WA' 'NE' 'OH' 'MO' 'AL' 'NH' 'NM' 'OR' 'TX' 'MS'
#  'WY' 'FL' 'KS' 'NC' 'SD' 'OK' 'CT' 'RI' 'DE' 'UT' 'NV' 'DC' 'ME' 'IL'
#  'NJ' 'MD' 'WV' 'PA' 'ND' 'AR' 'TN' 'IA' 'GA']
# International plan
# ['No' 'Yes']
# Voice mail plan
# ['No' 'Yes']

# %%
#no. of unique values and theri counts in cat columns
for i in cat:
    print(Tel_data[i].value_counts())
# Out:
# State
# AZ    19
# WA    18
# NM    18
# NJ    18
# WV    18
# KS    18
# ND    18
# WI    17
# ID    17
# RI    17
# IN    17
# TX    17
# MS    17
# KY    16
# LA    16
# VT    16
# NE    16
# OR    16
# NY    15
# MT    15
# MI    15
# CT    15
# AL    14
# MN    14
# NH    13
# MA    13
# ME    13
# IL    13
# OH    12
# NC    12
# TN    12
# UT    12
# MO    12
# WY    11
# SC    11
# SD    11
# VA    10
# DE    10
# CA    10
# MD    10
# OK     9
# AK     9
# HI     9
# PA     9
# FL     9
# DC     9
# AR     8
# CO     7
# IA     6
# NV     5
# GA     5
# Name: count, dtype: int64
# International plan
# No     614
# Yes     53
# Name: count, dtype: int64
# Voice mail plan
# No     478
# Yes    189
# Name: count, dtype: int64

# %%
for i in cat:
    print(i)
    print(Tel_data[i].nunique())
# Out:
# State
# 51
# International plan
# 2
# Voice mail plan
# 2

# %%
Tel_data['Churn'].value_counts(normalize=True)

#85% have not churned/ left company as a customer
# 14% have churned
#imbalanced data means the target variable is skweing a lot towards one output than the other
# Out:
# Churn
# False    0.857571
# True     0.142429
# Name: proportion, dtype: float64

# %%
#60% and 40% is not considered skwed
# 75% and 25% is def skwed. Its subjective tho

# %%
for i in cat:
    print(Tel_data[i].value_counts(normalize=True))

    #0.28 of the entire data is from AZ
    #92% of ppl are not in international plan 
    # 30 ke neeche if we have, we consider it as imbalanced data
# Out:
# State
# AZ    0.028486
# WA    0.026987
# NM    0.026987
# NJ    0.026987
# WV    0.026987
# KS    0.026987
# ND    0.026987
# WI    0.025487
# ID    0.025487
# RI    0.025487
# IN    0.025487
# TX    0.025487
# MS    0.025487
# KY    0.023988
# LA    0.023988
# VT    0.023988
# NE    0.023988
# OR    0.023988
# NY    0.022489
# MT    0.022489
# MI    0.022489
# CT    0.022489
# AL    0.020990
# MN    0.020990
# NH    0.019490
# MA    0.019490
# ME    0.019490
# IL    0.019490
# OH    0.017991
# NC    0.017991
# TN    0.017991
# UT    0.017991
# MO    0.017991
# WY    0.016492
# SC    0.016492
# SD    0.016492
# VA    0.014993
# DE    0.014993
# CA    0.014993
# MD    0.014993
# OK    0.013493
# AK    0.013493
# HI    0.013493
# PA    0.013493
# FL    0.013493
# DC    0.013493
# AR    0.011994
# CO    0.010495
# IA    0.008996
# NV    0.007496
# GA    0.007496
# Name: proportion, dtype: float64
# International plan
# No     0.92054
# Yes    0.07946
# Name: proportion, dtype: float64
# ...

# %%
# distribution is for one variable
# and normal distribution is for continuous/numerical variable.

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# entire data or the dataframe gets sorted according to the account length
Tel_data.sort_values(by='Account length',ascending=False) #its descen
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 300    NM             232        408                 No              No
# 218    TX             217        408                 No              No
# 42     WY             215        510                 No              No
# 640    NY             209        415                 No              No
# 525    SC             209        510                 No              No
# ..    ...             ...        ...                ...             ...
# 284    NV               7        408                 No             Yes
# 28     MO               6        510                 No              No
# 138    CT               3        415                 No             Yes
# 480    AK               1        408                 No              No
# 189    MS               1        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
Tel_data.sort_values(by='Customer service calls',ascending= False)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 313    SC              64        510                 No             Yes
# 579    GA             136        415                 No              No
# 582    NC              95        408                 No              No
# 299    MS              73        415                 No             Yes
# 149    WI             165        510                 No              No
# ..    ...             ...        ...                ...             ...
# 158    ME             151        415                 No             Yes
# 625    NH             123        408                 No              No
# 627    LA              91        415                 No              No
# 629    WV              73        415                 No              No
# 632    NE              67        415                 No             Yes
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
Tel_data.sort_values(by=['Customer service calls','Account length'],ascending= False)


# first sort the data in descending order of customer service calls. 
# then in say places where the customer service calls are repeating -- like 6,6,6 -- sort that according to the account length in descending order.
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 313    SC              64        510                 No             Yes
# 579    GA             136        415                 No              No
# 149    WI             165        510                 No              No
# 155    UT             103        510                 No             Yes
# 398    WA             100        408                 No              No
# ..    ...             ...        ...                ...             ...
# 162    TN              33        415                 No             Yes
# 29     AL              32        510                 No              No
# 597    OH              32        415                 No             Yes
# 136    MT              27        510                 No              No
# 375    NE              21        510                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
Tel_data['Number vmail messages'].mean()
# Out:
# np.float64(8.407796101949025)

# %%
Tel_data[num].groupby(['Churn']).sum()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# Churn
# False           58708     249218                   5143           100363.2
# True             9887      41699                    465            20329.2
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# Churn
# False            57644          17062.09           114285.4            57227
# True              9681           3456.01            21352.6             9791
#
#        Total eve charge  Total night minutes  Total night calls  \
# Churn
# False           9714.29             113722.4              57348
# True            1814.98              19467.7               9428
#
#        Total night charge  Total intl minutes  Total intl calls  \
# Churn
# False             5117.53              5858.8              2581
# True               876.07               970.2               439
#
#        Total intl charge  Customer service calls
# Churn
# ...

# %%
round(Tel_data[['Account length','Churn']].groupby(['Churn']).mean(),2)
# Out:
#        Account length
# Churn
# False          102.64
# True           104.07

# %%
round(Tel_data[num].groupby(['Churn']).mean(),2)
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# Churn
# False          102.64     435.70                   8.99             175.46
# True           104.07     438.94                   4.89             213.99
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# Churn
# False           100.78             29.83             199.80           100.05
# True            101.91             36.38             224.76           103.06
#
#        Total eve charge  Total night minutes  Total night calls  \
# Churn
# False             16.98               198.82             100.26
# True              19.11               204.92              99.24
#
#        Total night charge  Total intl minutes  Total intl calls  \
# Churn
# False                8.95               10.24              4.51
# True                 9.22               10.21              4.62
#
#        Total intl charge  Customer service calls
# Churn
# ...

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
round(Tel_data.pivot_table(

    values = ['Account length','Total day calls','Total eve calls'],
    index= ['International plan','Churn'],
    aggfunc = 'mean'

),  2)
# Out:
#                           Account length  Total day calls  Total eve calls
# International plan Churn
# No                 False          102.18           100.38           100.08
#                    True           104.67           102.89           103.83
# Yes                False          109.88           107.03            99.53
#                    True           101.68            97.95           100.00

# %%
round(Tel_data.pivot_table(

    values = ['Account length','Total day calls','Total eve calls'],

    index = ['State','Churn'],

    columns = ['International plan'],

    aggfunc = 'mean'

), 2)
# Out:
#                    Account length        Total day calls         \
# International plan             No    Yes              No    Yes
# State Churn
# AK    False                 80.00    NaN           98.33    NaN
# AL    False                101.00    NaN           98.00    NaN
#       True                    NaN   55.0             NaN   91.0
# AR    False                107.62    NaN           89.00    NaN
# AZ    False                 96.00   92.0           95.35   88.0
# ...                           ...    ...             ...    ...
# WI    True                 153.00  109.0          103.00   93.5
# WV    False                 99.47    NaN           97.40    NaN
#       True                  44.00  133.5          121.00  111.5
# WY    False                102.89  127.0          110.11   99.0
#       True                 134.00    NaN           93.00    NaN
#
#                    Total eve calls
# International plan              No    Yes
# State Churn
# ...

# %%
round(Tel_data.pivot_table(

    values = ['Account length','Total day calls','Total eve calls'],
    index = ['State','Churn'],
    aggfunc = 'mean') , 2
)

#AK has no True that means nobody churned from AK state.
# Out:
#              Account length  Total day calls  Total eve calls
# State Churn
# AK    False           80.00            98.33           101.44
# AL    False          101.00            98.00            99.54
#       True            55.00            91.00           110.00
# AR    False          107.62            89.00            86.38
# AZ    False           95.78            94.94            99.78
# ...                     ...              ...              ...
# WI    True           123.67            96.67            94.33
# WV    False           99.47            97.40            91.40
#       True           103.67           114.67            93.00
# WY    False          105.30           109.00            97.90
#       True           134.00            93.00           117.00
#
# [93 rows x 3 columns]

# %%
State_wise_churn_data= Tel_data.pivot_table(

    values = ['Account length','Total day calls','Total eve calls'],
    index = ['State','Churn'],
    
    aggfunc = ['mean','count']
)

#all the values column are numerical columns only so that can be averaged out and can be taken count of.

# %%
round(State_wise_churn_data,2)
# Out:
#                       mean                                          count  \
#             Account length Total day calls Total eve calls Account length
# State Churn
# AK    False          80.00           98.33          101.44              9
# AL    False         101.00           98.00           99.54             13
#       True           55.00           91.00          110.00              1
# AR    False         107.62           89.00           86.38              8
# AZ    False          95.78           94.94           99.78             18
# ...                    ...             ...             ...            ...
# WI    True          123.67           96.67           94.33              3
# WV    False          99.47           97.40           91.40             15
#       True          103.67          114.67           93.00              3
# WY    False         105.30          109.00           97.90             10
# ...

# %%
#this is useful when i want to analyse what happened with the people who left us ie. wherever the churn = True -- analyse that data.


churn_wise_state_data = Tel_data.pivot_table(

    values= ['Account length','Total day calls','Total eve calls'],
    index = ['Churn','State'],

    aggfunc= ['mean','count']
)

churn_wise_state_data
# Out:
#                       mean                                          count  \
#             Account length Total day calls Total eve calls Account length
# Churn State
# False AK         80.000000       98.333333      101.444444              9
#       AL        101.000000       98.000000       99.538462             13
#       AR        107.625000       89.000000       86.375000              8
#       AZ         95.777778       94.944444       99.777778             18
#       CA        108.666667      118.333333       95.500000              6
# ...                    ...             ...             ...            ...
# True  VT        111.500000      110.500000       66.000000              2
#       WA         94.250000       95.250000       99.750000              4
#       WI        123.666667       96.666667       94.333333              3
#       WV        103.666667      114.666667       93.000000              3
# ...

# %% [markdown]
# #### Pictorial EDA
#
# 1. Unviariate(one variable at a time)
# 2. Bivariate( two variables at a time)
# 3. Multivariate (2+variables)

# %%
#Unvivariate
# state : categorical variable  -- ie. count. we go for countplot
# what are the number of states?
#  Account length : numerical variable (continuous or discrete )

# ie. Age(in completed years) is a discrete variable. 
# ie. temperature can take any value ie. continuous variable. eg. Account Length
# ie. distribution (distplot, histogram,boxplot(outliers))

# %%
#categorical variables 

#matplotlib, seaborn

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
sns.countplot(data= Tel_data,x = 'International plan')
# Out:
# <Axes: xlabel='International plan', ylabel='count'>

# %%
Tel_data['International plan']= Tel_data['International plan'].replace({
    
        "Yes" : "International",
        "No" : "National"
    }
)

# %%
ax=sns.countplot(data= Tel_data, x= 'International plan')
ax.set(title = 'Plan distribution',xlabel = 'International plan', ylabel = 'count')
plt.show()

# %%
#Numerical variables
ax = sns.displot(data = Tel_data, x = 'Account length')
ax.set(title = 'Plan Distribution',xlabel = 'Account length', ylabel= 'Number of customers')
plt.show()

#account length is a discrete variable that is either i went for two days or went for three days

#distribution tells us that in case we find outliers, how should we treat those outliers.

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
ax = sns.histplot(data = Tel_data, x = 'Total day charge' )
ax.set(title = 'Plan distribution',xlabel = 'Total day charge', ylabel = 'No. of customers')
plt.show()

# %%
ax = sns.boxplot(data = Tel_data, x= 'Total day charge')
ax.set(title='Plan Distribution', xlabel = 'Total day charge', ylabel= 'No of Customers')
plt.show()

# %%
num
# Out:
# ['Account length',
#  'Area code',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
for i in num:
    ax = sns.boxplot(data=Tel_data, x= i)
    ax.set(title = '{} Distribution'.format(i),xlabel = '{} charge'.format(i),ylabel = 'No of Customers')
    plt.show()

# %%
Tel_data.drop('Churn',axis =1)
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408           National              No
# 1      IN              65        415           National              No
# 2      NY             161        415           National              No
# 3      SC             111        415           National              No
# 4      HI              49        510           National              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415           National             Yes
# 663    AL             106        408           National             Yes
# 664    VT              60        415           National              No
# 665    WV             159        415           National              No
# 666    CT             184        510      International              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# # SUBPLOTS

# %%
plt.figure(figsize=(20,5))
fig, axes =plt.subplots(nrows = 2, ncols = 3)



ax = sns.boxplot(data = Tel_data, x= 'Account length' , ax = axes[0][0])
ax.set(title='Account length',xlabel = '',ylabel = 'No of Customers')

ax = sns.boxplot(data = Tel_data, x= 'Number vmail messages' , ax = axes[0][1])
ax.set(title='Number vmail messages',xlabel = 'Number vmail messages',ylabel = 'No of Customers')

ax = sns.boxplot(data = Tel_data, x= 'Total day calls' , ax = axes[0][2])
ax.set(title='Total day calls',xlabel = 'Total day calls',ylabel = 'No of Customers')

ax = sns.boxplot(data = Tel_data, x= 'Total night calls' , ax = axes[1][0])
ax.set(title='Total night calls',xlabel = 'Total night calls',ylabel = 'No of Customers')

ax = sns.boxplot(data = Tel_data, x= 'Total intl calls' , ax = axes[1][1])
ax.set(title='Total intl calls',xlabel = 'Total intl calls',ylabel = 'No of Customers')

ax = sns.boxplot(data = Tel_data, x= 'Total intl calls' , ax = axes[1][2])
ax.set(title='Total intl calls',xlabel = 'Total intl calls',ylabel = 'No of Customers')

plt.subplots_adjust(left = 0.2, right = 0.9, bottom = 0.1, top= 0.9, wspace = 0.2, hspace =0.4)

# %%
Tel_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
num
# Out:
# ['Account length',
#  'Area code',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
# correlation lies between 1 and -1.
# zero means there is no correlation
# 1 means there is strong a very positiove correlation if a increases, b increases in the same direction 
# and a decreases b also decreases in the same direction to the same extent. 

# if you keep time constant, distance and speed will have a positive correlation of 1. 

# to be strong for correlation - this should be very close to 1 or -1.

# %%
len(num)
# Out:
# 17

# %%
# eg. account_length and number_vmail_messages are negatively correlated ie.
# -0.012 this correlation coefficient is very small.

# ie. account_length is not very much dependent on any of the variables. 
# it is pretty much independent. 


# correlation is only and only for numeric variables

# %%
round(Tel_data[num].corr(), 3)
# Out:
#                         Account length  Area code  Number vmail messages  \
# Account length                   1.000     -0.026                 -0.012
# Area code                       -0.026      1.000                 -0.007
# Number vmail messages           -0.012     -0.007                  1.000
# Total day minutes                0.018      0.052                 -0.069
# Total day calls                  0.036     -0.009                 -0.010
# Total day charge                 0.018      0.051                 -0.069
# Total eve minutes                0.027      0.017                  0.041
# Total eve calls                  0.021      0.018                 -0.052
# Total eve charge                 0.027      0.017                  0.041
# Total night minutes             -0.008     -0.017                  0.040
# Total night calls                0.027      0.036                  0.003
# Total night charge              -0.008     -0.017                  0.040
# ...

# %%
#plt.figure(figsize = (15,10))
sns.heatmap(round(Tel_data[num].corr(),3),annot = True)


# -1 dark colur --negative correlatio
# 1 is light colur --postiive correlation
# Out:
# <Axes: >

# %%
# 0.56 correlation coefficient means that 56% variability 
# in one can be used by variiability in another variable.
