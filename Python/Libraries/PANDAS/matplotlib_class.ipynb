# %%
#matplotlib is the libraray which helps with visualizations for 2-d plots. 
#built on top of numpy
#

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
import pandas as pd

#importing the titanic dataset

titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#line plot
x = [1,2,3,4,5]
y = [10,5,2,6,3]

# %%
plt.plot(x,y) #these are pairwise graphs. 
# here it is taking x and y as coordinates 
plt.show()

# %%
#bar plot

#it is very useful to see the frequency.

# %%
plt.bar(x,y)
# here it is taking 1 as the category and 10 as the frequency.
plt.show()

# %%
#scatter plot

plt.scatter(x,y)
plt.show()

# %%
#plotting the Age distribution
plt.plot(titanic['Age']) #line plot
plt.title('Age Distibution')
plt.xlabel('Passenger_Index')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # Plotting with Different Styles

# %%
#this is a horrible graph as it is not telling anything.

#customizing the plot
plt.plot(titanic['Age'],linestyle = '--',marker = 'o',color = 'r')
plt.title('Customised Age Distribution')
plt.xlabel('Passenger Index')
plt.ylabel('Age')
plt.show()

# %%
#Customizing plots
#Adding grid lines, adjusting plot limits and adding legends. 

plt.plot(titanic['Age'],color = 'g')
plt.title('Age distribution with Grid')
plt.xlabel('Passenger Index')
plt.ylabel('Age')
plt.grid(True)
plt.xlim(0,100)
plt.ylim(0,80)
plt.legend(['Age'])
plt.show()

# %% [markdown]
# # Subplots and Layouts

# %%
#creating multiple subplots and adjusting their layouts

# %%
titanic.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
#creating multiple subplots
fig,axs = plt.subplots(2,2)
axs[0,0].plot(titanic['Age'],color = 'b')
axs[0,0].set_title('Age Distribution')
axs[0,1].plot(titanic['Fare'],color = 'r')
axs[0,1].set_title('Fare Distribution')
axs[1,0].plot(titanic['SibSp'],color = 'g')
axs[1,0].set_title('SibSp Distribution')
axs[1,1].plot(titanic['Parch'],color='m')
axs[1,1].set_title('Parents/Childer Abroad')

fig.tight_layout()
plt.show()

# %%
# Annotations and Text

# Adding annotations and customizing text properties

# %%
#Adding annotations
plt.plot(titanic['Age'],color = 'b')
plt.title('Age distribution with annotation')
plt.xlabel('Passenger Index')
plt.ylabel('Age')
plt.annotate('Oldest Passenger', xy = (600,80), xytext=(400,60),
             
             arrowprops=dict(facecolor = 'black',shrink = 0.05)
             
             )
plt.show()

# %%
titanic.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
#Plotting different types of data
# creating bar plots, histograms, pie charts, scatter plots and boxplots

# %%
#Bar Plot

#bar plot is good for categorical variables where there is a stop. 

pclass_counts = titanic['Pclass'].value_counts()
plt.bar(pclass_counts.index, pclass_counts.values, color = ['r','g','b'])
plt.title('Passenger Class distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Class distribution')

# %%
#Histogram

#for histogram ie. for continuous variables histogram is good. 
plt.hist(titanic['Age'].dropna(),bins = 30, color = 'c')
plt.title('Age Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

#histogram values are continuous.

# %%
x = [1,2,3,4,5]
y = [10,5,2,6,3]
plt.plot(x,y)
plt.xlabel('X value')
plt.ylabel('Y value')
plt.title("Bargraph")
plt.show()

# %%
#Bar plot

plt.bar(x,y,edgecolor = 'red')
plt.plot(x,y,color = "black")
plt.show()

# %%
data = np.random.randn(1000) #normal distribution. 
data
# Out:
# array([-5.25009907e-01,  8.93779354e-01, -5.14974876e-01, -2.62064388e-01,
#         1.77200214e+00, -6.13597812e-02,  3.95177247e-01,  1.05092909e+00,
#         4.44001869e-01, -2.32692583e-01, -3.25776176e-01,  2.14803962e-01,
#         4.88007645e-01, -1.76565422e-01,  2.43204932e-01,  1.86641192e+00,
#         1.13105324e+00, -4.63431615e-01, -3.08409984e-01,  3.97490689e-01,
#        -1.38497961e+00, -1.61903134e+00,  3.66125898e-01, -2.64066381e-01,
#         8.37048163e-01, -1.57127060e+00, -3.27033163e-01,  3.17624539e-01,
#         5.06253588e-01, -1.03538841e+00,  1.35801373e+00,  1.06437073e+00,
#         1.09035361e-01, -1.43811836e+00, -9.49228945e-01,  5.08197220e-01,
#        -1.58654118e-01,  1.54477761e-01,  3.39122905e-01,  4.94083732e-01,
#        -5.45956444e-01,  2.67946532e-01,  1.23490143e-01, -1.70235837e-02,
#        -1.11679347e+00, -1.23363721e+00, -1.80696277e+00,  2.99975060e-01,
# ...

# %%
len(data) #1000 values in the data.
# Out:
# 1000

# %%
plt.hist(data, bins = 30)
plt.show()

# %%
#this histogram got divided in the bins of 10. 

plt.hist(titanic['Age'],bins = 20)
plt.show()

# %%
titanic['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# # for example there is a series of numbers:
#
# data: 4,5,9,10,11,13,14,19
#
# Ways to find bins:
#
# 1st Method:
#
# Maximum is 19,
# minimum is 4
# ie. bin-width = (19-4)/total_number_of_bins_you_want = (19-4)/3 = (15)/3 = 5
# bin1 : 4+5 = 9 ie. [4,9)
# bin2 : 9+5 =14 ie. [9,14)
# bin3 : 14+5= 19 ie. [14,19]
# Next, sort the data into these bins:
# Bin 1: 4, 5
# Bin 2: 9, 10, 11, 13
# Bin 3: 14, 19
#
# 2nd Method:
# on the basis of the frequency
#
# ie. I want three bins. so that would be
#
# bin1: 4,5,9
# bin2: 10,11,13
# bin3: 14,19

# %%
import matplotlib.pyplot as plt

# Data and bins
data = [4, 5, 9, 10, 11, 13, 14, 19]
bins = [4, 9, 14, 19]

# Plot histogram
plt.hist(data, bins=bins, edgecolor='black', alpha=0.7)

# Adding titles and labels
plt.title("Histogram of Data with Bin Width 5")
plt.xlabel("Value Range")
plt.ylabel("Frequency")

# Show plot
plt.show()

# %%
plt.hist(titanic['Age'],bins = 10,edgecolor = 'black')
plt.show()

# %%
titanic['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# max is 80 and min is 0
#
# and lets say i want 15 bins ie.
#
# (max-min)/15
#
# (80-0.42)/15 = 5.33
#
# so the first bin is 0.42 +5.33 = 5.75 ie bin is [0.42,5.75)
#
# so bin starts preparing from 0.42 ends at 5.75

# %%
titanic['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
plt.hist(titanic['Age'],bins =15,edgecolor ='black')
plt.show()

# %%
plt.hist(titanic['Age'],bins = 10, edgecolor = 'black')
plt.show()

# %%
#pearson coefficient correltaion. 
# used for scatter plot.

# %%
plt.scatter(x,y,marker="*")
plt.grid(True)
plt.show()

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import seaborn as sns
sns.pairplot(titanic)

# %%
#Subplot

2X2 matrix

[ 1   2
  3   4  ]

#It has 3 parameters:
1. Number of rows: 2
2.number of cols : 2
3. plot number: wwhere you want to draw your graph.

# %%
plt.subplot(2,2,4) #the last argument is the position where you want to keep the graph placed. keep this at 4th position.
plt.hist(titanic['Age'], bins =8, edgecolor = "black")
plt.subplot(2,2,1) #keep it at 1st position. 
plt.scatter(x,y)
plt.show()

# %%
for i in range(1,10):
    plt.subplot(3,3,i)
    plt.bar(x,y)

plt.show()

# %%
plt.hist(titanic['Age'],bins=8,edgecolor ='black',label="Age info")

plt.plot(x,y,label = "aline") #label means it gives the legend.

plt.xlabel('Age')
plt.ylabel('Frequency')

plt.xlim(0,100)
plt.ylim(0,500)
plt.grid(True)

plt.xticks(np.arange(0,100,5))
plt.yticks([0,200,300],['Min','Med','Max'])
plt.tight_layout()
plt.legend()
plt.show()

plt.savefig('Age Frequen.png')

# %%
#Major arguments

1. plt.xlim()/plt.ylim() : set the limits for x-axis and y-axis resp.
2. plt.xticks() / plt.yticks() : set the location and labels of ticks 
3. plt.grid()
4. plt.legend()
5. plt.tight_layout()
6. plt.savefig()
7. plt.subplots_adjust()
8. plt.axhline()
9. plt.text()
10. plt.annotate()

# %%
x= np.linspace(0,10,100)#generates equally spaced numbers between 0 and 100. 
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.plot(x,y1,label = "Sin")
plt.plot(x,y2,label = "Cos")

plt.grid()
plt.tight_layout()
plt.legend(loc = "upper right")



plt.xlabel('X axis label')
plt.ylabel('Y axis label')
plt.title('Plotting Sin and Cosine')
plt.xlim(0,10)
plt.ylim(-1,1)
plt.xticks(np.arange(0,11,2))
plt.yticks([-1,0,1],['Min','Mid','Max'])
plt.grid(True)

plt.annotate('origin', (0,0),color = 'red')
#annotation is at x=0 and y=0
plt.annotate('HighestVale',xy=(3.14,1))

plt.text(3,0,"I am here")



plt.show()

# %%
#creating 3d plots, contour plots, quiver plots and histogram

# %%
#3d plot
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax= fig.add_subplot(111,projection = '3d')
ax.scatter(titanic['Age'],titanic['Fare'],titanic['Pclass'],c='r',marker='o')
ax.set_title(' 3d plot of age, fare and class')
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.set_zlabel('Class')
plt.show()

# %%
#countour plot
import numpy as np
X,Y = np.meshgrid(np.linspace(-5,5,100),np.linspace(-5,5,100))
Z= np.sin(np.sqrt(X**2 + Y**2))
plt.contour(X,Y,Z)
plt.title('Contour plot')
plt.xlabel('X axis')
plt.ylabel('y axis')
plt.show()

# %%
#Heatmap
matrix = np.random.random((10,10))
plt.imshow(matrix, cmap='hot', interpolation ='nearest')
plt.title('Heatmap')
plt.colorbar()
plt.show()

# %%
#customizing plot appearance
#customizing plot aesthetics, using stylesheets and creating custom styles

# %%
#customing plot aesthetics
plt.style.use('ggplot')
plt.plot(titanic['Age'],color= 'b')
plt.title('Age distribution with ggplot style')
plt.xlabel('Passenger index')
plt.ylabel('Age')
plt.show()

# %%
#working with time series data
# plotting time series and formatting date and time labels

# %%
titanic['Date'] = pd.date_range(start= '1/1/2020',periods = len(titanic),freq='D')
plt.plot(titanic['Date'],titanic['Age'])
plt.title('Age over time')
plt.xlabel('Date')
plt.ylabel('Age')
plt.xticks(rotation =45)
plt.show()

# %%
titanic['Date']
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 886   2022-06-05
# 887   2022-06-06
# 888   2022-06-07
# 889   2022-06-08
# 890   2022-06-09
# Name: Date, Length: 891, dtype: datetime64[ns]

# %%
#Interactive plots
#using widgets for interactive plots

from ipywidgets import interact

def plot_histogram(bin_size):
    plt.hist(titanic['Age'].dropna(),bins = bin_size,color='c')
    plt.title('Histogram of Age: {}'.format(bin_size))
    plt.xlabel('Age')
    plt.ylabel('Frequecny')
    plt.show()

interact(plot_histogram,bin_size = (5,50,5))

# %%
# Combining multiple plots
fig,ax = plt.subplots(3, 2, figsize=(15,15),dpi=500) #dots per inch. 

# Age distribution
ax[0, 0].hist(titanic['Age'].dropna(), bins=30, color='c')
ax[0, 0].set_title('Age Distribution')
ax[0, 0].set_xlabel('Age')
ax[0, 0].set_ylabel('Frequency')

# Fare distribution
ax[0, 1].hist(titanic['Fare'], bins=30, color='orange')
ax[0, 1].set_title('Fare Distribution')
ax[0, 1].set_xlabel('Fare')
ax[0, 1].set_ylabel('Frequency')

# Survival distribution
survived_counts = titanic['Survived'].value_counts()
ax[1, 0].pie(survived_counts, labels=['Not Survived', 'Survived'], autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
ax[1, 0].set_title('Survival Distribution')

# Passenger class distribution
pclass_counts = titanic['Pclass'].value_counts()
ax[1, 1].bar(pclass_counts.index, pclass_counts.values, color=['blue', 'yellow', 'green'])
ax[1, 1].set_title('Passenger Class Distribution')
ax[1, 1].set_xlabel('Class')
ax[1, 1].set_ylabel('Number of Passengers')

# Age vs Fare scatter plot
ax[2, 0].scatter(titanic['Age'], titanic['Fare'], alpha=0.5, color='purple')
ax[2, 0].set_title('Age vs Fare')
ax[2, 0].set_xlabel('Age')
ax[2, 0].set_ylabel('Fare')

# Age box plot
ax[2, 1].boxplot(titanic['Age'].dropna())
ax[2, 1].set_title('Age Boxplot')
ax[2, 1].set_ylabel('Age')

plt.tight_layout()
plt.show()

# %%
p1 = pd.DataFrame(titanic['Sex'].value_counts())
p1
# Out:
#         count
# Sex
# male      577
# female    314

# %%
p1['count']
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.bar(['male','female'],p1['count'])
# Out:
# <BarContainer object of 2 artists>
