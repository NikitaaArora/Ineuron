# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
x = [1,2,3,4,5]
y = [10,5,2,6,3]

# %%
fig = plt.figure()  

ax = fig.add_axes([0,0,2,1])

ax.plot(x,y)
ax.set_title('X vs Y')
ax.set_xlim(-4,4)
ax.set_xlabel('X values')
ax.set_label('X vs Y')

# %%
#subplots
fig,ax = plt.subplots(3,2) #firgure just creates the blank canvas rest everything we do using ax.

ax[0,0].scatter(x,y)

ax[0,1].bar(x,y)

ax[1,0].plot(x,y)

# %%
a = (1,2,3)
a
# Out:
# (1, 2, 3)

# %%
a,b,c = (1,2,3)

# %%
a,b,c
# Out:
# (1, 2, 3)

# %%
a[1]
# Out:
# 2

# %%
ax = (1,2,3)

# %%
ax
# Out:
# (1, 2, 3)

# %%
ax1,ax2,ax3 = (1,2,3)

# %%
ax2
# Out:
# 2

# %%
ax1
# Out:
# 1

# %%
ax3
# Out:
# 3

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize = (6,8))

ax1.plot(x,y)
ax2.scatter(x,y)

fig.savefig('myfavgraph.png')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#seaborn works with dataframes insead of x and y

# %%
x = [1,2,3,4,5]
y= [10,5,2,6,3]

# %%
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd

#importing the titanic dataset

titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.dtypes
#all the int64 can be used for scatter plots.
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#seaborn is a library to make graphs with datafrmaes
# matplotlib doesnt understand dfs

# %%
sns.pairplot(titanic)

# %%
#python statistical graphic library
# it is built on top of matplotlib
# It incorporates matplotlib with pandas. 
# its plotting function work on dataframes and arrays creating entire datasets. 
# but seaborn cant do customisations properly.

# %%
data = pd.DataFrame({'Category': ['A','A','B','B','C','C'],
                     'Value': [1,2,3,4,5,6],
                     'Value2':[10,20,30,40,50,60]})

# %%
data
# Out:
#   Category  Value  Value2
# 0        A      1      10
# 1        A      2      20
# 2        B      3      30
# 3        B      4      40
# 4        C      5      50
# 5        C      6      60

# %%
sns.scatterplot(data, x= 'Category',y='Value')
plt.show()

# %%
sns.set_theme(style="dark")
sns.lineplot(data, x='Category',y='Value2')
plt.show() #seaborn is on top of matplotlib hence it doesnt show.

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.load_dataset("iris")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = "whitegrid")

#load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

#draw a scatter plot while assigning point colours and sizes to different variables
# in the dataset

f,ax = plt.subplots(figsize = (6.5,6.5))
ax.set_title("Mygraph")
sns.despine(f,left=True,bottom= True)
clarity_ranking = ["I1","SI2","SI1","VS2","VS1","VVS2","VVS1","IF"]
sns.scatterplot(x="carat",y="price",
                hue="clarity",size = "depth",
                palette="ch:r=.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes = (1,8),linewidth = 0,
                data=diamonds, ax=ax)
# Out:
# <Axes: title={'center': 'Mygraph'}, xlabel='carat', ylabel='price'>

# %%
sns.histplot(data, x= 'Category', y= 'Value')
# Out:
# <Axes: xlabel='Category', ylabel='Value'>

# %%
sns.violinplot(data,x='Category',y='Value')
# Out:
# <Axes: xlabel='Category', ylabel='Value'>
