# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
x = [1,2,3,4,5]
y = [10,5,2,6,3]

# %%
fig = plt.figure()  

ax = fig.add_axes([0,0,2,1])

ax.plot(x,y)
